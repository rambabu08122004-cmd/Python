# %% [markdown]
# <a href="https://colab.research.google.com/github/rambabu08122004-cmd/Python/blob/main/Pythonfile1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# starting python
'''hi, this is
first day of
python class'''
print("Hello")
# Out:
# Hello

# %%
print("Name : Ram Babu")
print("Age : 21")
print("Qualification : Graduation")
# Out:
# Name : Ram Babu
# Age : 21
# Qualification : Graduation
