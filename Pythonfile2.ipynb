# %% [markdown]
# <a href="https://colab.research.google.com/github/rambabu08122004-cmd/Python/blob/main/Pythonfile2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=5
y=3
print(x+y)
# Out:
# 8

# %%
price_of_burger = 150
price_of_pizza = 450
price_of_coke = 80
price_of_latte = 250
price_of_pastry = 140
Total_price = price_of_burger + price_of_coke + price_of_pizza + price_of_latte +price_of_pastry
print("price_of_burger = ", price_of_burger)
print("price_of_pizza  = ", price_of_pizza)
print("price_of_coke   = ", price_of_coke)
print("price_of_latte  = ", price_of_latte)
print("price_of_pastry = ", price_of_pastry)
print("------------------------")
print("Total bill      = ", Total_price)
# Out:
# price_of_burger =  150
# price_of_pizza  =  450
# price_of_coke   =  80
# price_of_latte  =  250
# price_of_pastry =  140
# ------------------------
# Total bill      =  1070

# %%
First_Number  = 5
Second_Number = 10
print("First_Number  = ", First_Number)
print("Second_Number = ", Second_Number)
print("Sum           = ", First_Number + Second_Number)
print("Difference    = " ,  First_Number - Second_Number)
print("Multiply      = "  , First_Number*Second_Number)
print("Division      = " , First_Number/Second_Number)
# Out:
# First_Number  =  5
# Second_Number =  10
# Sum           =  15
# Difference    =  -5
# Multiply      =  50
# Division      =  0.5
